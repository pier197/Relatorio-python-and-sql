# %%
import pandas as pd 
import sqlite3
import sql

# %% [markdown]
# # Acesando o banco de dados mysql

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:umadalpe2019@localhost:3306/gestao_pessoas

# %%
# %%sql
#
# select *
# from gestao
# LIMIT 8;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/gestao_pessoas
# 8 rows affected.
# [(41, 'sim', 'Raramente', 1102, 'vendas', 1, 2, 'ciÃªncias biolÃ³gicas', 1, 1, 2, 'Feminino', 94, 3, 2, 'Executivo de vendas', 4, 'Solteiro(a)', 5993, 19479, 8, 'Sim', 'Sim', 11, 3, 1, 80, 0, 8, 0, 1, 6, 4, 0, 5),
#  (49, 'nÃ£o', 'Frequentemente', 279, 'Pesquisa e desenvolvimento', 8, 1, 'ciÃªncias biolÃ³gicas', 1, 2, 3, 'Masculino', 61, 2, 2, 'Cientista pesquisador ', 2, 'Casado(a)', 5130, 24907, 1, 'Sim', 'NÃ£o', 23, 4, 4, 80, 1, 10, 3, 3, 10, 7, 1, 7),
#  (37, 'sim', 'Raramente', 1373, 'Pesquisa e desenvolvimento', 2, 2, 'Outros', 1, 4, 4, 'Masculino', 92, 2, 1, 'TÃ©cnico de laboratÃ³rio', 3, 'Solteiro(a)', 2090, 2396, 6, 'Sim', 'Sim', 15, 3, 2, 80, 0, 7, 3, 3, 0, 0, 0, 0),
# ...

# %%
# %%sql
#
# select
#     Atrito,
#     Departamento,
#     genero,
#     Cargo,
#     Estado_Civil,
#     Num_Empresas_Trabalhadas
#
# from gestao
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/gestao_pessoas
# 10 rows affected.
# [('sim', 'vendas', 'Feminino', 'Executivo de vendas', 'Solteiro(a)', 8),
#  ('nÃ£o', 'Pesquisa e desenvolvimento', 'Masculino', 'Cientista pesquisador ', 'Casado(a)', 1),
#  ('sim', 'Pesquisa e desenvolvimento', 'Masculino', 'TÃ©cnico de laboratÃ³rio', 'Solteiro(a)', 6),
#  ('nÃ£o', 'Pesquisa e desenvolvimento', 'Feminino', 'Cientista pesquisador ', 'Casado(a)', 1),
#  ('nÃ£o', 'Pesquisa e desenvolvimento', 'Masculino', 'TÃ©cnico de laboratÃ³rio', 'Casado(a)', 9),
#  ('nÃ£o', 'Pesquisa e desenvolvimento', 'Masculino', 'TÃ©cnico de laboratÃ³rio', 'Solteiro(a)', 0),
#  ('nÃ£o', 'Pesquisa e desenvolvimento', 'Feminino', 'TÃ©cnico de laboratÃ³rio', 'Casado(a)', 4),
#  ('nÃ£o', 'Pesquisa e desenvolvimento', 'Masculino', 'TÃ©cnico de laboratÃ³rio', 'Divorciado(a)', 1),
#  ('nÃ£o', 'Pesquisa e desenvolvimento', 'Masculino', 'Diretor de Manufatura', 'Solteiro(a)', 0),
# ...

# %%
# %%sql
#
# select COUNT(*)
# from gestao
# where genero ='Feminino'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/gestao_pessoas
# 1 rows affected.
# [(588,)]

# %%
# %%sql
#
# select COUNT(*)
# from gestao
# where (genero = "feminino" and Cargo = "TÃ©cnico de laboratÃ³rio")
# Out:
#  * mysql+pymysql://root:***@localhost:3306/gestao_pessoas
# 1 rows affected.
# [(85,)]

# %%
# %%sql
#
# select *
# from gestao
# where genero = "Feminino" and (Idade BETWEEN 30 and 49)
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/gestao_pessoas
# 10 rows affected.
# [(41, 'sim', 'Raramente', 1102, 'vendas', 1, 2, 'ciÃªncias biolÃ³gicas', 1, 1, 2, 'Feminino', 94, 3, 2, 'Executivo de vendas', 4, 'Solteiro(a)', 5993, 19479, 8, 'Sim', 'Sim', 11, 3, 1, 80, 0, 8, 0, 1, 6, 4, 0, 5),
#  (33, 'nÃ£o', 'Frequentemente', 1392, 'Pesquisa e desenvolvimento', 3, 4, 'ciÃªncias biolÃ³gicas', 1, 5, 4, 'Feminino', 56, 3, 1, 'Cientista pesquisador ', 3, 'Casado(a)', 2909, 23159, 1, 'Sim', 'Sim', 11, 3, 3, 80, 0, 8, 3, 3, 8, 7, 3, 0),
#  (34, 'nÃ£o', 'Raramente', 419, 'Pesquisa e desenvolvimento', 7, 4, 'ciÃªncias biolÃ³gicas', 1, 28, 1, 'Feminino', 53, 3, 3, 'Diretor de pesquisa', 2, 'Solteiro(a)', 11994, 21293, 0, 'Sim', 'NÃ£o', 11, 3, 3, 80, 0, 13, 4, 3, 12, 6, 2, 11),
# ...

# %%
# %%sql
#
# Select AVG(Idade) AS average from gestao
# Out:
#  * mysql+pymysql://root:***@localhost:3306/gestao_pessoas
# 1 rows affected.
# [(Decimal('36.9238'),)]

# %%
# %sql select Idade,Cargo from gestao order by Idade DESC LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/gestao_pessoas
# 10 rows affected.
# [(60, 'Executivo de vendas'),
#  (60, 'Executivo de vendas'),
#  (60, 'Profissional de SaÃºde'),
#  (60, 'gerente'),
#  (60, 'Executivo de vendas'),
#  (59, 'Diretor de Manufatura'),
#  (59, 'Recursos Humanos'),
#  (59, 'gerente'),
#  (59, 'gerente'),
#  (59, 'TÃ©cnico de laboratÃ³rio')]

# %%
data = %sql select * from gestao

df =data.DataFrame()

df.head()
# Out:
#  * mysql+pymysql://root:***@localhost:3306/gestao_pessoas
# 1470 rows affected.
#    Idade Atrito Viagem_a_negÃ³cios  DiÃ¡ria                Departamento  \
# 0     41    sim          Raramente     1102                      vendas
# 1     49   nÃ£o     Frequentemente      279  Pesquisa e desenvolvimento
# 2     37    sim          Raramente     1373  Pesquisa e desenvolvimento
# 3     33   nÃ£o     Frequentemente     1392  Pesquisa e desenvolvimento
# 4     27   nÃ£o          Raramente      591  Pesquisa e desenvolvimento
#
#    Distancia_de_casa  Educacao       Area_de_formacao  \
# 0                  1         2  ciÃªncias biolÃ³gicas
# 1                  8         1  ciÃªncias biolÃ³gicas
# 2                  2         2                 Outros
# 3                  3         4  ciÃªncias biolÃ³gicas
# 4                  2         1                 Medica
#
#    Contagem_de_ funcionÃ¡rios  Numero_de _empregado  ...  \
# 0                           1                     1  ...
# ...

# %%
df.rename(columns={'Viagem_a_negÃ³cios': 'viagem_a_negocios','DiÃ¡ria':'diaria','Contagem_de_ funcionÃ¡rios':'contagem_de_funcionarios','HorÃ¡rio PadrÃ£o':'horario_padrao'}, inplace = True)

# %%
df.head()
# Out:
#    Idade Atrito viagem_a_negocios  diaria                Departamento  \
# 0     41    sim         Raramente    1102                      vendas
# 1     49   nÃ£o    Frequentemente     279  Pesquisa e desenvolvimento
# 2     37    sim         Raramente    1373  Pesquisa e desenvolvimento
# 3     33   nÃ£o    Frequentemente    1392  Pesquisa e desenvolvimento
# 4     27   nÃ£o         Raramente     591  Pesquisa e desenvolvimento
#
#    Distancia_de_casa  Educacao       Area_de_formacao  \
# 0                  1         2  ciÃªncias biolÃ³gicas
# 1                  8         1  ciÃªncias biolÃ³gicas
# 2                  2         2                 Outros
# 3                  3         4  ciÃªncias biolÃ³gicas
# 4                  2         1                 Medica
#
#    contagem_de_funcionarios  Numero_de _empregado  ...  \
# 0                         1                     1  ...
# 1                         1                     2  ...
# ...

# %%
df.rename(columns={'NÃ­vel_de_ opÃ§Ã£o _de _aÃ§Ãµes':'nivel_de_opcoes','HorÃ¡rios_de_Treinamento_ÃšltimoAno':'horario_de_treinamento','EquilÃ­brio_ vida_ profissional':'equilibro_vida_profissional','Anos_na _FunÃ§Ã£o_Atual':'anos_na_funcao_atual'}, inplace = True)

# %%
df.head()
# Out:
#    Idade Atrito viagem_a_negocios  diaria                Departamento  \
# 0     41    sim         Raramente    1102                      vendas
# 1     49   nÃ£o    Frequentemente     279  Pesquisa e desenvolvimento
# 2     37    sim         Raramente    1373  Pesquisa e desenvolvimento
# 3     33   nÃ£o    Frequentemente    1392  Pesquisa e desenvolvimento
# 4     27   nÃ£o         Raramente     591  Pesquisa e desenvolvimento
#
#    Distancia_de_casa  Educacao       Area_de_formacao  \
# 0                  1         2  ciÃªncias biolÃ³gicas
# 1                  8         1  ciÃªncias biolÃ³gicas
# 2                  2         2                 Outros
# 3                  3         4  ciÃªncias biolÃ³gicas
# 4                  2         1                 Medica
#
#    contagem_de_funcionarios  Numero_de _empregado  ...  \
# 0                         1                     1  ...
# 1                         1                     2  ...
# ...

# %% [markdown]
# ## Substituindo valores

# %%
df= df.replace(['nÃ£o'],'nao')

# %%
#mostra as 10 primeiras linhas
df.head(10)
# Out:
#    Idade Atrito viagem_a_negocios  diaria                Departamento  \
# 0     41    sim         Raramente    1102                      vendas
# 1     49    nao    Frequentemente     279  Pesquisa e desenvolvimento
# 2     37    sim         Raramente    1373  Pesquisa e desenvolvimento
# 3     33    nao    Frequentemente    1392  Pesquisa e desenvolvimento
# 4     27    nao         Raramente     591  Pesquisa e desenvolvimento
# 5     32    nao    Frequentemente    1005  Pesquisa e desenvolvimento
# 6     59    nao         Raramente    1324  Pesquisa e desenvolvimento
# 7     30    nao         Raramente    1358  Pesquisa e desenvolvimento
# 8     38    nao    Frequentemente     216  Pesquisa e desenvolvimento
# 9     36    nao         Raramente    1299  Pesquisa e desenvolvimento
#
#    Distancia_de_casa  Educacao       Area_de_formacao  \
# 0                  1         2  ciÃªncias biolÃ³gicas
# 1                  8         1  ciÃªncias biolÃ³gicas
# ...

# %%
df= df.replace(['ciÃªncias biolÃ³gicas'],'ciencias biologica')

# %%
df.head()
# Out:
#    Idade Atrito viagem_a_negocios  diaria                Departamento  \
# 0     41    sim         Raramente    1102                      vendas
# 1     49    nao    Frequentemente     279  Pesquisa e desenvolvimento
# 2     37    sim         Raramente    1373  Pesquisa e desenvolvimento
# 3     33    nao    Frequentemente    1392  Pesquisa e desenvolvimento
# 4     27    nao         Raramente     591  Pesquisa e desenvolvimento
#
#    Distancia_de_casa  Educacao    Area_de_formacao  contagem_de_funcionarios  \
# 0                  1         2  ciencias biologica                         1
# 1                  8         1  ciencias biologica                         1
# 2                  2         2              Outros                         1
# 3                  3         4  ciencias biologica                         1
# 4                  2         1              Medica                         1
#
#    Numero_de _empregado  ...  Relacionamento_satisfacao horario_padrao  \
# ...

# %% [markdown]
# # Transformação dos dados

# %%
df.dtypes
# Out:
# Idade                               int64
# Atrito                             object
# viagem_a_negocios                  object
# diaria                              int64
# Departamento                       object
# Distancia_de_casa                   int64
# Educacao                            int64
# Area_de_formacao                   object
# contagem_de_funcionarios            int64
# Numero_de _empregado                int64
# Satisfacao_Ambiental                int64
# genero                             object
# Taxa horÃ¡ria                       int64
# Envolvimento_no _Trabalho           int64
# NÃ­vel de emprego                   int64
# Cargo                              object
# SatisfaÃ§Ã£o_no _Trabalho           int64
# Estado_Civil                       object
# Renda_ Mensal                       int64
# Taxa_Mensal                         int64
# Num_Empresas_Trabalhadas            int64
# acima_de_ 18                       object
# ...

# %%
#exibe as colunas da base de dados
df.columns
# Out:
# Index(['Idade', 'Atrito', 'viagem_a_negocios', 'diaria', 'Departamento',
#        'Distancia_de_casa', 'Educacao', 'Area_de_formacao',
#        'contagem_de_funcionarios', 'Numero_de _empregado',
#        'Satisfacao_Ambiental', 'genero', 'Taxa horÃ¡ria',
#        'Envolvimento_no _Trabalho', 'NÃ­vel de emprego', 'Cargo',
#        'SatisfaÃ§Ã£o_no _Trabalho', 'Estado_Civil', 'Renda_ Mensal',
#        'Taxa_Mensal', 'Num_Empresas_Trabalhadas', 'acima_de_ 18',
#        'Horas_extra', 'Percentual_de_Aumento_SalÃ¡rio',
#        'AvaliaÃ§Ã£o_de _desempenho', 'Relacionamento_satisfacao',
#        'horario_padrao', 'nivel_de_opcoes', 'Total_de _anos _de_ trabalho',
#        'horario_de_treinamento', 'equilibro_vida_profissional',
#        'AnosNaEmpresa', 'anos_na_funcao_atual',
#        'Anos_desde_ a_ ultima_ promocao', 'Ano_ com_o atual_ gerente'],
#       dtype='object')

# %%
#exibe total de colunas e linhas
df.shape
# Out:
# (1470, 35)

# %%
#resumo estatistico 
df.describe()
# Out:
#              Idade       diaria  Distancia_de_casa     Educacao  \
# count  1470.000000  1470.000000        1470.000000  1470.000000
# mean     36.923810   802.485714           9.192517     2.912925
# std       9.135373   403.509100           8.106864     1.024165
# min      18.000000   102.000000           1.000000     1.000000
# 25%      30.000000   465.000000           2.000000     2.000000
# 50%      36.000000   802.000000           7.000000     3.000000
# 75%      43.000000  1157.000000          14.000000     4.000000
# max      60.000000  1499.000000          29.000000     5.000000
#
#        contagem_de_funcionarios  Numero_de _empregado  Satisfacao_Ambiental  \
# count                    1470.0           1470.000000           1470.000000
# mean                        1.0           1024.865306              2.721769
# std                         0.0            602.024335              1.093082
# min                         1.0              1.000000              1.000000
# ...

# %%
#resumo das colunas especificas
df[['Idade','AnosNaEmpresa']].describe()
# Out:
#              Idade  AnosNaEmpresa
# count  1470.000000    1470.000000
# mean     36.923810       7.008163
# std       9.135373       6.126525
# min      18.000000       0.000000
# 25%      30.000000       3.000000
# 50%      36.000000       5.000000
# 75%      43.000000       9.000000
# max      60.000000      40.000000

# %%
df[['Idade','AnosNaEmpresa','Renda_ Mensal']]
# Out:
#       Idade  AnosNaEmpresa  Renda_ Mensal
# 0        41              6           5993
# 1        49             10           5130
# 2        37              0           2090
# 3        33              8           2909
# 4        27              2           3468
# ...     ...            ...            ...
# 1465     36              5           2571
# 1466     39              7           9991
# 1467     27              6           6142
# 1468     49              9           5390
# 1469     34              4           4404
#
# [1470 rows x 3 columns]

# %%
df[3:20][['genero','AnosNaEmpresa']]
# Out:
#        genero  AnosNaEmpresa
# 3    Feminino              8
# 4   Masculino              2
# 5   Masculino              7
# 6    Feminino              1
# 7   Masculino              1
# 8   Masculino              9
# 9   Masculino              7
# 10  Masculino              5
# 11   Feminino              9
# 12  Masculino              5
# 13  Masculino              2
# 14  Masculino              4
# 15   Feminino             10
# 16  Masculino              6
# 17  Masculino              1
# 18   Feminino             25
# 19  Masculino              3

# %% [markdown]
# ## Tratamento de dados vazios(NaN) ou dados ausentes(NUL)

# %%
# isna
print(df.isna().sum())
# Out:
# Idade                              0
# Atrito                             0
# viagem_a_negocios                  0
# diaria                             0
# Departamento                       0
# Distancia_de_casa                  0
# Educacao                           0
# Area_de_formacao                   0
# contagem_de_funcionarios           0
# Numero_de _empregado               0
# Satisfacao_Ambiental               0
# genero                             0
# Taxa horÃ¡ria                      0
# Envolvimento_no _Trabalho          0
# NÃ­vel de emprego                  0
# Cargo                              0
# SatisfaÃ§Ã£o_no _Trabalho          0
# Estado_Civil                       0
# Renda_ Mensal                      0
# Taxa_Mensal                        0
# Num_Empresas_Trabalhadas           0
# acima_de_ 18                       0
# Horas_extra                        0
# Percentual_de_Aumento_SalÃ¡rio     0
# AvaliaÃ§Ã£o_de _desempenho         0
# ...

# %%
print(df.isnull().sum())
# Out:
# Idade                              0
# Atrito                             0
# viagem_a_negocios                  0
# diaria                             0
# Departamento                       0
# Distancia_de_casa                  0
# Educacao                           0
# Area_de_formacao                   0
# contagem_de_funcionarios           0
# Numero_de _empregado               0
# Satisfacao_Ambiental               0
# genero                             0
# Taxa horÃ¡ria                      0
# Envolvimento_no _Trabalho          0
# NÃ­vel de emprego                  0
# Cargo                              0
# SatisfaÃ§Ã£o_no _Trabalho          0
# Estado_Civil                       0
# Renda_ Mensal                      0
# Taxa_Mensal                        0
# Num_Empresas_Trabalhadas           0
# acima_de_ 18                       0
# Horas_extra                        0
# Percentual_de_Aumento_SalÃ¡rio     0
# AvaliaÃ§Ã£o_de _desempenho         0
# ...

# %% [markdown]
# ## Contagem distintas

# %%
#contagem dos valores distintos
df['Cargo'].value_counts()
# Out:
# Executivo de vendas         326
# Cientista pesquisador       292
# TÃ©cnico de laboratÃ³rio    259
# Diretor de Manufatura       145
# Profissional de SaÃºde      131
# gerente                     102
# Representante de vendas      83
# Diretor de pesquisa          80
# Recursos Humanos             52
# Name: Cargo, dtype: int64

# %%
df['Departamento'].value_counts()
# Out:
# Pesquisa e desenvolvimento    961
# vendas                        446
# Recursos Humanos               63
# Name: Departamento, dtype: int64

# %%
df['genero'].value_counts()
# Out:
# Masculino    882
# Feminino     588
# Name: genero, dtype: int64

# %% [markdown]
# ### Convertendo no formato csv

# %%
df.to_csv()
# Out:
# ',Idade,Atrito,viagem_a_negocios,diaria,Departamento,Distancia_de_casa,Educacao,Area_de_formacao,contagem_de_funcionarios,Numero_de _empregado,Satisfacao_Ambiental,genero,Taxa horÃ¡ria,Envolvimento_no _Trabalho,NÃ\xadvel de emprego,Cargo,SatisfaÃ§Ã£o_no _Trabalho,Estado_Civil,Renda_ Mensal,Taxa_Mensal,Num_Empresas_Trabalhadas,acima_de_ 18,Horas_extra,Percentual_de_Aumento_SalÃ¡rio,AvaliaÃ§Ã£o_de _desempenho,Relacionamento_satisfacao,horario_padrao,nivel_de_opcoes,Total_de _anos _de_ trabalho,horario_de_treinamento,equilibro_vida_profissional,AnosNaEmpresa,anos_na_funcao_atual,Anos_desde_ a_ ultima_ promocao,Ano_ com_o atual_ gerente\r\n0,41,sim,Raramente,1102,vendas,1,2,ciencias biologica,1,1,2,Feminino,94,3,2,Executivo de vendas,4,Solteiro(a),5993,19479,8,Sim,Sim,11,3,1,80,0,8,0,1,6,4,0,5\r\n1,49,nao,Frequentemente,279,Pesquisa e desenvolvimento,8,1,ciencias biologica,1,2,3,Masculino,61,2,2,Cientista pesquisador ,2,Casado(a),5130,24907,1,Sim,NÃ£o,23,4,4,80,1,10,3,3,10,7,1,7\r\n2,37,
# ...
